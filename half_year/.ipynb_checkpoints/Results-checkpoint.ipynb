# %%
import pandas as pd
import numpy as np

# %%
res = pd.read_csv('result.csv').drop(columns = ['Unnamed: 0'])

# %%
res_all = res.loc[res['Features'] == 'All']

# %%
res_MRT = res.loc[res['Features'] == 'MRT']

# %%
res_clinical = res.loc[res['Features'] == 'Clinical']

# %%
res_clinical.groupby('Calibration_split_bound').mean()
# Out:
#                               ACC  Dataset_number       FPR        R2  \
# Calibration_split_bound
# 0.1                      0.148899               1  5.044444 -2.163750
# 0.2                      0.154597               1  5.200000 -2.224545
# 0.3                      0.152983               1  5.033333 -2.098206
# 0.4                      0.146917               1  4.955556 -2.096636
# 0.5                      0.155422               1  5.344444 -2.199602
# 0.6                      0.149610               1  4.888889 -2.213991
# 0.7                      0.158719               1  5.655556 -2.126770
# 0.8                      0.159687               1  5.433333 -2.228584
# 0.9                      0.148472               1  5.000000 -2.090209
#
#                               RMSE   ROC AUC        TPR  log_loss
# Calibration_split_bound
# 0.1                      45.857753  0.983874   9.277778  0.941042
# 0.2                      46.257473  0.982095   9.866667  0.938726
# 0.3                      44.040522  0.982461  10.233333  0.939446
# 0.4                      43.434523  0.983926   9.677778  0.940750
# 0.5                      45.801533  0.982005   9.933333  0.937333
# 0.6                      45.813155  0.982378  10.933333  0.938995
# 0.7                      44.053879  0.982623   9.600000  0.935745
# 0.8                      46.209351  0.981415  10.566667  0.935290
# 0.9                      44.002651  0.983080  10.244444  0.939438

# %%
res_MRT.groupby('Calibration_split_bound').mean()
# Out:
#                               ACC  Dataset_number       FPR        R2  \
# Calibration_split_bound
# 0.1                      0.399540               1  8.511111 -2.312113
# 0.2                      0.400595               1  6.022222 -2.252451
# 0.3                      0.390913               1  7.711111 -2.389983
# 0.4                      0.392552               1  7.588889 -2.213452
# 0.5                      0.398000               1  6.566667 -2.376499
# 0.6                      0.383596               1  6.800000 -2.233192
# 0.7                      0.390182               1  8.177778 -2.396857
# 0.8                      0.392407               1  6.866667 -2.365388
# 0.9                      0.409964               1  7.722222 -2.214649
#
#                               RMSE   ROC AUC        TPR  log_loss
# Calibration_split_bound
# 0.1                      45.931060  0.829090  52.433333  0.823971
# 0.2                      46.166066  0.824482  59.733333  0.828952
# 0.3                      47.091202  0.826441  54.177778  0.829254
# 0.4                      45.296555  0.825887  55.622222  0.824613
# 0.5                      47.757745  0.827576  57.555556  0.828346
# 0.6                      45.469736  0.829447  55.644444  0.832745
# 0.7                      46.259950  0.825390  50.266667  0.831093
# 0.8                      47.438692  0.829164  57.533333  0.825764
# 0.9                      45.322445  0.819427  54.755556  0.822539

# %%
res_all.groupby('Calibration_split_bound').mean()
# Out:
#                               ACC  Dataset_number       FPR        R2  \
# Calibration_split_bound
# 0.1                      0.154604               1  4.266667 -0.185246
# 0.2                      0.148219               1  4.011111 -0.151749
# 0.3                      0.156388               1  3.722222 -0.074712
# 0.4                      0.145771               1  3.966667 -0.190758
# 0.5                      0.154465               1  3.866667 -0.152805
# 0.6                      0.143316               1  3.900000 -0.201665
# 0.7                      0.143361               1  3.900000 -0.208678
# 0.8                      0.143459               1  4.400000 -0.295145
# 0.9                      0.142614               1  4.044444 -0.217432
#
#                               RMSE   ROC AUC        TPR  log_loss
# Calibration_split_bound
# 0.1                      27.196054  0.982231  13.244444  0.938867
# 0.2                      26.634929  0.982089  13.144444  0.940882
# 0.3                      25.102312  0.981765  14.788889  0.939189
# 0.4                      27.445965  0.983379  13.022222  0.941549
# 0.5                      26.123577  0.981607  14.888889  0.937356
# 0.6                      28.239913  0.983321  12.200000  0.944082
# 0.7                      27.252724  0.982890  13.200000  0.942063
# 0.8                      29.379366  0.982512  10.944444  0.943157
# 0.9                      27.972134  0.982749  12.900000  0.941789
